# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
import torch
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torchvision.datasets import ImageFolder
import os
from torch.optim import lr_scheduler
from torch.optim.lr_scheduler import ReduceLROnPlateau
import pretrainedmodels
from adamW import AdamW
from lr_finder import LRFinder

# %%
# !ls lrdata/coffee_table/style/train
# Out:
# Asian	      Craftsman   Mediterranean  Rustic        Tropical
# Beach Style   Farmhouse   Midcentury	 Traditional   Victorian
# Contemporary  Industrial  Modern	 Transitional

# %%
#Example code for only one of my attribute training sets
path = 'Osamadata/basecolorboth'

# %%
from PIL import Image
#NOTE: CHANGE THIS IF YOU WANT TO SWITCH DIR
#removes images from training set that are corrupt.
images_path = 'Osamadata/basecolor/valid'
image_extensions = ['.jpg', '.png', '.jpeg']
images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(images_path)
         for f in filenames if os.path.splitext(f)[1].lower() in image_extensions]

for i, item in enumerate(images):
    try:
        im = Image.open(item)
    except IOError:
        os.remove(item)
        print('removed '+ item)

# %%
#this is necessary because all of the images in my training set are symbolic links
def loadsymlink(path):
    returnImage = Image.open(os.readlink(path))
    return returnImage.convert('RGB')

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
        transforms.Compose([
            transforms.Resize((224,224)),
            transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize
        ]),
    'valid':
        transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            normalize
        ])
}

image_datasets = {
    'train':
        ImageFolder(os.path.join(path,'train'), data_transforms['train']),
    'valid':
        ImageFolder(os.path.join('Osamadata/basecolorboth','valid'), data_transforms['valid'])}

dataloaders = {
    'train':
        torch.utils.data.DataLoader(
            image_datasets['train'],
            batch_size=8,
            shuffle=True,
            num_workers=4),
    'valid':
        torch.utils.data.DataLoader(
            image_datasets['valid'],
            batch_size=8,
            shuffle=False,
            num_workers=4)}

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = models.resnet50(pretrained=True).to(device)

#good LR always happens to be small for AdamW
optimizer = AdamW(model.parameters(), lr=1e-5, weight_decay=1e-4)
#optimizer = optim.SGD(model.parameters(), lr=1e-2, weight_decay=1e-4)

num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 16).to(device)

criterion = nn.CrossEntropyLoss()

print("creating learning rate scheduler")


steps = len(dataloaders['train'])
exp_lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, steps)
# Out:
# creating learning rate scheduler

# %%
#typically I get my best lr right before the descent in loss, make sure to set lr = 1e-8 before running
lr_finder = LRFinder(model, optimizer, criterion, device='cuda')
lr_finder.range_test(dataloaders['train'], end_lr=1, num_iter=100)
lr_finder.plot()

# %%
def train_model(model, criterion, optimizer, dataloaders, scheduler=None, num_epochs=20,cycle_mult=1):

    steps = len(dataloaders['train'])
    completed = 0
    
    best_acc = 0.0
    
    dataset_sizes = {'train':len(dataloaders['train'].dataset),'valid':len(dataloaders['valid'].dataset)}
    
    #wandb.watch(model)
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)
 
        epoch_loss = 1.0

        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
 
            running_loss = 0.0
            running_corrects = 0
 
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
 
                outputs = model(inputs)
                loss = criterion(outputs, labels)
 
                if phase == 'train':
                    if scheduler is not None:
                        steps -= 1
                        scheduler.step()
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                    
 
                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
 
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
        
            if phase == 'valid':
                #wandb.log({'epoch_loss':epoch_loss,'epoch_acc':epoch_acc})
                
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = model.state_dict()
        
        
        if scheduler is not None:
            lrval = scheduler.get_lr()[0]
            print('steps: %d lr: %.8f'%(steps,lrval))
            
        if (steps <= 0):
            steps = len(dataloaders['train'])
            print(steps)
            scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, steps)

        print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                    epoch_loss,
                                                    epoch_acc))    
    
    #torch.save(best_model_wts, 'testsave.pt')
    return model

# %%
#shade shape
#product bv
model_trained = train_model(model, criterion, optimizer, dataloaders, scheduler=None, num_epochs=75, cycle_mult=2)
# Out:
# Epoch 1/75
# ----------
# valid loss: 2.5319, acc: 0.3023
# Epoch 2/75
# ----------
# valid loss: 2.1013, acc: 0.4884
# Epoch 3/75
# ----------
# valid loss: 1.6923, acc: 0.5116
# Epoch 4/75
# ----------
# valid loss: 1.5440, acc: 0.5581
# Epoch 5/75
# ----------
# valid loss: 1.4170, acc: 0.5698
# Epoch 6/75
# ----------
# valid loss: 1.3801, acc: 0.5581
# Epoch 7/75
# ----------
# valid loss: 1.3727, acc: 0.5465
# Epoch 8/75
# ----------
# valid loss: 1.3250, acc: 0.5581
# Epoch 9/75
# ----------
# valid loss: 1.2556, acc: 0.6395
# Epoch 10/75
# ----------
# valid loss: 1.2574, acc: 0.6279
# Epoch 11/75
# ----------
# valid loss: 1.2373, acc: 0.6163
# Epoch 12/75
# ----------
# valid loss: 1.2688, acc: 0.6512
# Epoch 13/75
# ----------
# valid loss: 1.2811, acc: 0.6744
# Epoch 14/75
# ----------
# valid loss: 1.3502, acc: 0.6512
# Epoch 15/75
# ----------
# valid loss: 1.2682, acc: 0.6279
# Epoch 16/75
# ----------
# valid loss: 1.3471, acc: 0.6628
# Epoch 17/75
# ----------
# valid loss: 1.3744, acc: 0.6860
# Epoch 18/75
# ----------
# valid loss: 1.2719, acc: 0.6628
# Epoch 19/75
# ----------
# valid loss: 1.2746, acc: 0.6744
# Epoch 20/75
# ----------
# valid loss: 1.4103, acc: 0.6279
# Epoch 21/75
# ----------
# valid loss: 1.4408, acc: 0.6628
# Epoch 22/75
# ----------
# valid loss: 1.3552, acc: 0.6860
# Epoch 23/75
# ----------
# valid loss: 1.3546, acc: 0.6628
# Epoch 24/75
# ----------
# valid loss: 1.3932, acc: 0.6395
# Epoch 25/75
# ----------
# valid loss: 1.4675, acc: 0.6395
# Epoch 26/75
# ----------
# valid loss: 1.4418, acc: 0.6512
# Epoch 27/75
# ----------
# valid loss: 1.3498, acc: 0.6744
# Epoch 28/75
# ----------
# valid loss: 1.3211, acc: 0.6860
# Epoch 29/75
# ----------
# valid loss: 1.5326, acc: 0.6512
# Epoch 30/75
# ----------
# valid loss: 1.3051, acc: 0.6512
# Epoch 31/75
# ----------
# valid loss: 1.3812, acc: 0.6977
# Epoch 32/75
# ----------
# valid loss: 1.4890, acc: 0.6628
# Epoch 33/75
# ----------
# valid loss: 1.4677, acc: 0.6512
# Epoch 34/75
# ----------
# valid loss: 1.4770, acc: 0.6512
# Epoch 35/75
# ----------
# valid loss: 1.4588, acc: 0.6512
# Epoch 36/75
# ----------
# valid loss: 1.4183, acc: 0.6628
# Epoch 37/75
# ----------
# valid loss: 1.4143, acc: 0.6744
# Epoch 38/75
# ----------
# valid loss: 1.4530, acc: 0.6512
# Epoch 39/75
# ----------
# valid loss: 1.5247, acc: 0.6744
# Epoch 40/75
# ----------
# valid loss: 1.5247, acc: 0.6744
# Epoch 41/75
# ----------
# valid loss: 1.4592, acc: 0.6628
# Epoch 42/75
# ----------
# valid loss: 1.4601, acc: 0.6512
# Epoch 43/75
# ----------
# valid loss: 1.5355, acc: 0.6977
# Epoch 44/75
# ----------
# valid loss: 1.5175, acc: 0.6628
# Epoch 45/75
# ----------
# valid loss: 1.4385, acc: 0.6395
# Epoch 46/75
# ----------
# valid loss: 1.5903, acc: 0.6163
# Epoch 47/75
# ----------
# valid loss: 1.5993, acc: 0.6163
# Epoch 48/75
# ----------
# valid loss: 1.6506, acc: 0.6512
# Epoch 49/75
# ----------
# valid loss: 1.7062, acc: 0.6163
# Epoch 50/75
# ----------
# valid loss: 1.5457, acc: 0.6395
# Epoch 51/75
# ----------
# valid loss: 1.6689, acc: 0.6977
# Epoch 52/75
# ----------
# valid loss: 1.5131, acc: 0.6860
# Epoch 53/75
# ----------
# valid loss: 1.5482, acc: 0.6628
# Epoch 54/75
# ----------
# valid loss: 1.6901, acc: 0.6860
# Epoch 55/75
# ----------
# valid loss: 1.5271, acc: 0.6512
# Epoch 56/75
# ----------
# valid loss: 1.4637, acc: 0.6395
# Epoch 57/75
# ----------
# valid loss: 1.6108, acc: 0.6512
# Epoch 58/75
# ----------
# valid loss: 1.6463, acc: 0.6628
# Epoch 59/75
# ----------
# valid loss: 1.5261, acc: 0.6279
# Epoch 60/75
# ----------
# valid loss: 1.6287, acc: 0.6512
# Epoch 61/75
# ----------
# valid loss: 1.4999, acc: 0.6744
# Epoch 62/75
# ----------
# valid loss: 1.6143, acc: 0.6395
# Epoch 63/75
# ----------
# valid loss: 1.5432, acc: 0.6628
# Epoch 64/75
# ----------
# valid loss: 1.4401, acc: 0.6512
# Epoch 65/75
# ----------
# valid loss: 1.4997, acc: 0.6512
# Epoch 66/75
# ----------
# valid loss: 1.4064, acc: 0.6744
# Epoch 67/75
# ----------
# valid loss: 1.4876, acc: 0.6860
# Epoch 68/75
# ----------
# valid loss: 1.4487, acc: 0.6860
# Epoch 69/75
# ----------
# valid loss: 1.4515, acc: 0.6628
# Epoch 70/75
# ----------
# valid loss: 1.5277, acc: 0.6163
# Epoch 71/75
# ----------
# valid loss: 1.5097, acc: 0.6512
# Epoch 72/75
# ----------
# valid loss: 1.6218, acc: 0.6395
# Epoch 73/75
# ----------
# valid loss: 1.6322, acc: 0.6512
# Epoch 74/75
# ----------
# valid loss: 1.5830, acc: 0.6395
# Epoch 75/75
# ----------
# valid loss: 1.5884, acc: 0.6512

# %%
#product and cropped bv
model_trained = train_model(model, criterion, optimizer, dataloaders, scheduler=None, num_epochs=75, cycle_mult=2)
# Out:
# Epoch 1/75
# ----------
# valid loss: 2.6173, acc: 0.2326
# Epoch 2/75
# ----------
# valid loss: 2.1130, acc: 0.4186
# Epoch 3/75
# ----------
# valid loss: 1.8152, acc: 0.4767
# Epoch 4/75
# ----------
# valid loss: 1.6445, acc: 0.5233
# Epoch 5/75
# ----------
# valid loss: 1.3787, acc: 0.5698
# Epoch 6/75
# ----------
# valid loss: 1.3809, acc: 0.5349
# Epoch 7/75
# ----------
# valid loss: 1.2985, acc: 0.6047
# Epoch 8/75
# ----------
# valid loss: 1.2065, acc: 0.6047
# Epoch 9/75
# ----------
# valid loss: 1.2213, acc: 0.5814
# Epoch 10/75
# ----------
# valid loss: 1.2174, acc: 0.6512
# Epoch 11/75
# ----------
# valid loss: 1.1770, acc: 0.6279
# Epoch 12/75
# ----------
# valid loss: 1.2113, acc: 0.6512
# Epoch 13/75
# ----------
# valid loss: 1.1102, acc: 0.6512
# Epoch 14/75
# ----------
# valid loss: 1.1583, acc: 0.6628
# Epoch 15/75
# ----------
# valid loss: 1.1462, acc: 0.6977
# Epoch 16/75
# ----------
# valid loss: 1.1311, acc: 0.6860
# Epoch 17/75
# ----------
# valid loss: 1.1486, acc: 0.6860
# Epoch 18/75
# ----------
# valid loss: 1.1309, acc: 0.6860
# Epoch 19/75
# ----------
# valid loss: 1.1872, acc: 0.7093
# Epoch 20/75
# ----------
# valid loss: 1.1945, acc: 0.6860
# Epoch 21/75
# ----------
# valid loss: 1.1964, acc: 0.7093
# Epoch 22/75
# ----------
# valid loss: 1.2810, acc: 0.7093
# Epoch 23/75
# ----------
# valid loss: 1.2923, acc: 0.6860
# Epoch 24/75
# ----------
# valid loss: 1.1776, acc: 0.7442
# Epoch 25/75
# ----------
# valid loss: 1.2577, acc: 0.6628
# Epoch 26/75
# ----------
# valid loss: 1.2444, acc: 0.6860
# Epoch 27/75
# ----------
# valid loss: 1.2087, acc: 0.7209
# Epoch 28/75
# ----------
# valid loss: 1.2475, acc: 0.7093
# Epoch 29/75
# ----------
# valid loss: 1.3507, acc: 0.6744
# Epoch 30/75
# ----------
# valid loss: 1.2669, acc: 0.6860
# Epoch 31/75
# ----------
# valid loss: 1.3676, acc: 0.6395
# Epoch 32/75
# ----------
# valid loss: 1.2319, acc: 0.7093
# Epoch 33/75
# ----------
# valid loss: 1.3825, acc: 0.6744
# Epoch 34/75
# ----------
# valid loss: 1.2959, acc: 0.7093
# Epoch 35/75
# ----------
# valid loss: 1.2221, acc: 0.6744
# Epoch 36/75
# ----------
# valid loss: 1.3249, acc: 0.6977
# Epoch 37/75
# ----------
# valid loss: 1.2087, acc: 0.7209
# Epoch 38/75
# ----------
# valid loss: 1.2463, acc: 0.6860
# Epoch 39/75
# ----------
# valid loss: 1.2843, acc: 0.6744
# Epoch 40/75
# ----------
# valid loss: 1.2187, acc: 0.7326
# Epoch 41/75
# ----------
# valid loss: 1.1782, acc: 0.6977
# Epoch 42/75
# ----------
# valid loss: 1.3111, acc: 0.6628
# Epoch 43/75
# ----------
# valid loss: 1.2694, acc: 0.6744
# Epoch 44/75
# ----------
# valid loss: 1.2760, acc: 0.7093
# Epoch 45/75
# ----------
# valid loss: 1.3296, acc: 0.6395
# Epoch 46/75
# ----------
# valid loss: 1.2264, acc: 0.6860
# Epoch 47/75
# ----------
# valid loss: 1.4271, acc: 0.6395
# Epoch 48/75
# ----------
# valid loss: 1.2475, acc: 0.6744
# Epoch 49/75
# ----------
# valid loss: 1.2109, acc: 0.6860
# Epoch 50/75
# ----------
# valid loss: 1.1842, acc: 0.6744
# Epoch 51/75
# ----------
# valid loss: 1.3808, acc: 0.6744
# Epoch 52/75
# ----------
# valid loss: 1.1850, acc: 0.7442
# Epoch 53/75
# ----------
# valid loss: 1.2948, acc: 0.7209
# Epoch 54/75
# ----------
# valid loss: 1.3305, acc: 0.6744
# Epoch 55/75
# ----------
# valid loss: 1.2110, acc: 0.7326
# Epoch 56/75
# ----------
# valid loss: 1.4001, acc: 0.6860
# Epoch 57/75
# ----------
# valid loss: 1.2553, acc: 0.7209
# Epoch 58/75
# ----------
# valid loss: 1.4713, acc: 0.6744
# Epoch 59/75
# ----------
# valid loss: 1.2984, acc: 0.6628
# Epoch 60/75
# ----------
# valid loss: 1.2633, acc: 0.6860
# Epoch 61/75
# ----------
# valid loss: 1.4720, acc: 0.6395
# Epoch 62/75
# ----------
# valid loss: 1.1995, acc: 0.7093
# Epoch 63/75
# ----------
# valid loss: 1.3021, acc: 0.7093
# Epoch 64/75
# ----------
# valid loss: 1.2073, acc: 0.6628
# Epoch 65/75
# ----------
# valid loss: 1.2023, acc: 0.6860
# Epoch 66/75
# ----------
# valid loss: 1.3102, acc: 0.6512
# Epoch 67/75
# ----------
# valid loss: 1.3231, acc: 0.6977
# Epoch 68/75
# ----------
# valid loss: 1.2910, acc: 0.7093
# Epoch 69/75
# ----------
# valid loss: 1.2397, acc: 0.6860
# Epoch 70/75
# ----------
# valid loss: 1.3859, acc: 0.7093
# Epoch 71/75
# ----------
# valid loss: 1.3488, acc: 0.6977
# Epoch 72/75
# ----------
# valid loss: 1.1664, acc: 0.7442
# Epoch 73/75
# ----------
# valid loss: 1.2332, acc: 0.6744
# Epoch 74/75
# ----------
# valid loss: 1.3595, acc: 0.6512
# Epoch 75/75
# ----------
# valid loss: 1.2962, acc: 0.6744

# %%
#base material
#product both valid
model_trained = train_model(model, criterion, optimizer, dataloaders, scheduler=None, num_epochs=75, cycle_mult=2)
# Out:
# Epoch 1/75
# ----------
# valid loss: 1.8174, acc: 0.3704
# Epoch 2/75
# ----------
# valid loss: 1.5966, acc: 0.4907
# Epoch 3/75
# ----------
# valid loss: 1.4428, acc: 0.5185
# Epoch 4/75
# ----------
# valid loss: 1.3585, acc: 0.5370
# Epoch 5/75
# ----------
# valid loss: 1.2804, acc: 0.5648
# Epoch 6/75
# ----------
# valid loss: 1.2480, acc: 0.6019
# Epoch 7/75
# ----------
# valid loss: 1.1942, acc: 0.6296
# Epoch 8/75
# ----------
# valid loss: 1.1834, acc: 0.6204
# Epoch 9/75
# ----------
# valid loss: 1.1695, acc: 0.6481
# Epoch 10/75
# ----------
# valid loss: 1.1655, acc: 0.6296
# Epoch 11/75
# ----------
# valid loss: 1.1198, acc: 0.6389
# Epoch 12/75
# ----------
# valid loss: 1.1900, acc: 0.6481
# Epoch 13/75
# ----------
# valid loss: 1.1372, acc: 0.6481
# Epoch 14/75
# ----------
# valid loss: 1.1947, acc: 0.6481
# Epoch 15/75
# ----------
# valid loss: 1.2451, acc: 0.6574
# Epoch 16/75
# ----------
# valid loss: 1.2125, acc: 0.6759
# Epoch 17/75
# ----------
# valid loss: 1.2383, acc: 0.6759
# Epoch 18/75
# ----------
# valid loss: 1.3596, acc: 0.6389
# Epoch 19/75
# ----------
# valid loss: 1.2288, acc: 0.6667
# Epoch 20/75
# ----------
# valid loss: 1.2609, acc: 0.6574
# Epoch 21/75
# ----------
# valid loss: 1.3298, acc: 0.6481
# Epoch 22/75
# ----------
# valid loss: 1.3884, acc: 0.6759
# Epoch 23/75
# ----------
# valid loss: 1.3738, acc: 0.6574
# Epoch 24/75
# ----------
# valid loss: 1.5111, acc: 0.6296
# Epoch 25/75
# ----------
# valid loss: 1.4485, acc: 0.6296
# Epoch 26/75
# ----------
# valid loss: 1.4902, acc: 0.6574
# Epoch 27/75
# ----------
# valid loss: 1.4354, acc: 0.6667
# Epoch 28/75
# ----------
# valid loss: 1.4558, acc: 0.6667
# Epoch 29/75
# ----------
# valid loss: 1.4204, acc: 0.6296
# Epoch 30/75
# ----------
# valid loss: 1.4522, acc: 0.6574
# Epoch 31/75
# ----------
# valid loss: 1.4888, acc: 0.6204
# Epoch 32/75
# ----------
# valid loss: 1.4535, acc: 0.6574
# Epoch 33/75
# ----------
# valid loss: 1.4814, acc: 0.6296
# Epoch 34/75
# ----------
# valid loss: 1.5632, acc: 0.6111
# Epoch 35/75
# ----------
# valid loss: 1.6128, acc: 0.6204
# Epoch 36/75
# ----------
# valid loss: 1.6023, acc: 0.6389
# Epoch 37/75
# ----------
# valid loss: 1.5056, acc: 0.6481
# Epoch 38/75
# ----------
# valid loss: 1.5032, acc: 0.6481
# Epoch 39/75
# ----------
# valid loss: 1.4775, acc: 0.6204
# Epoch 40/75
# ----------
# valid loss: 1.6230, acc: 0.6389
# Epoch 41/75
# ----------
# valid loss: 1.5416, acc: 0.6296
# Epoch 42/75
# ----------
# valid loss: 1.5359, acc: 0.6296
# Epoch 43/75
# ----------
# valid loss: 1.5660, acc: 0.6574
# Epoch 44/75
# ----------
# valid loss: 1.4769, acc: 0.6204
# Epoch 45/75
# ----------
# valid loss: 1.5708, acc: 0.5926
# Epoch 46/75
# ----------
# valid loss: 1.6513, acc: 0.6019
# Epoch 47/75
# ----------
# valid loss: 1.5766, acc: 0.6481
# Epoch 48/75
# ----------
# valid loss: 1.5176, acc: 0.6667
# Epoch 49/75
# ----------
# valid loss: 1.4400, acc: 0.6481
# Epoch 50/75
# ----------
# valid loss: 1.6411, acc: 0.6111
# Epoch 51/75
# ----------
# valid loss: 1.6840, acc: 0.5833
# Epoch 52/75
# ----------
# valid loss: 1.5845, acc: 0.6574
# Epoch 53/75
# ----------
# valid loss: 1.5994, acc: 0.6019
# Epoch 54/75
# ----------
# valid loss: 1.6405, acc: 0.6019
# Epoch 55/75
# ----------
# valid loss: 1.7578, acc: 0.6019
# Epoch 56/75
# ----------
# valid loss: 1.7300, acc: 0.6296
# Epoch 57/75
# ----------
# valid loss: 1.6520, acc: 0.6204
# Epoch 58/75
# ----------
# valid loss: 1.7637, acc: 0.6389
# Epoch 59/75
# ----------
# valid loss: 1.6851, acc: 0.6204
# Epoch 60/75
# ----------
# valid loss: 1.6638, acc: 0.6667
# Epoch 61/75
# ----------
# valid loss: 1.6588, acc: 0.6481
# Epoch 62/75
# ----------
# valid loss: 1.5693, acc: 0.6481
# Epoch 63/75
# ----------
# valid loss: 1.5285, acc: 0.7037
# Epoch 64/75
# ----------
# valid loss: 1.6765, acc: 0.6944
# Epoch 65/75
# ----------
# valid loss: 1.7589, acc: 0.6296
# Epoch 66/75
# ----------
# valid loss: 1.7072, acc: 0.6759
# Epoch 67/75
# ----------
# valid loss: 1.6545, acc: 0.6481
# Epoch 68/75
# ----------
# valid loss: 1.5441, acc: 0.6481
# Epoch 69/75
# ----------
# valid loss: 1.5446, acc: 0.6759
# Epoch 70/75
# ----------
# valid loss: 1.7033, acc: 0.6296
# Epoch 71/75
# ----------
# valid loss: 1.6872, acc: 0.6111
# Epoch 72/75
# ----------
# valid loss: 1.7721, acc: 0.6204
# Epoch 73/75
# ----------
# valid loss: 1.7643, acc: 0.6111
# Epoch 74/75
# ----------
# valid loss: 1.5985, acc: 0.6111
# Epoch 75/75
# ----------
# valid loss: 1.6396, acc: 0.6574

# %%
#Product and cropped both valid
model_trained = train_model(model, criterion, optimizer, dataloaders, scheduler=None, num_epochs=75, cycle_mult=2)
# Out:
# Epoch 1/75
# ----------
# valid loss: 1.8421, acc: 0.2963
# Epoch 2/75
# ----------
# valid loss: 1.5757, acc: 0.5278
# Epoch 3/75
# ----------
# valid loss: 1.4078, acc: 0.5926
# Epoch 4/75
# ----------
# valid loss: 1.3112, acc: 0.6296
# Epoch 5/75
# ----------
# valid loss: 1.1987, acc: 0.6574
# Epoch 6/75
# ----------
# valid loss: 1.1469, acc: 0.6389
# Epoch 7/75
# ----------
# valid loss: 1.1283, acc: 0.6481
# Epoch 8/75
# ----------
# valid loss: 1.0946, acc: 0.6481
# Epoch 9/75
# ----------
# valid loss: 1.0880, acc: 0.6296
# Epoch 10/75
# ----------
# valid loss: 1.0404, acc: 0.6852
# Epoch 11/75
# ----------
# valid loss: 1.0528, acc: 0.6667
# Epoch 12/75
# ----------
# valid loss: 1.0511, acc: 0.6667
# Epoch 13/75
# ----------
# valid loss: 0.9812, acc: 0.6944
# Epoch 14/75
# ----------
# valid loss: 1.0257, acc: 0.6944
# Epoch 15/75
# ----------
# valid loss: 1.0349, acc: 0.7037
# Epoch 16/75
# ----------
# valid loss: 1.0224, acc: 0.7037
# Epoch 17/75
# ----------
# valid loss: 1.0740, acc: 0.7037
# Epoch 18/75
# ----------
# valid loss: 1.0872, acc: 0.6944
# Epoch 19/75
# ----------
# valid loss: 1.1489, acc: 0.7130
# Epoch 20/75
# ----------
# valid loss: 1.1533, acc: 0.6759
# Epoch 21/75
# ----------
# valid loss: 1.1580, acc: 0.6944
# Epoch 22/75
# ----------
# valid loss: 1.1124, acc: 0.7315
# Epoch 23/75
# ----------
# valid loss: 1.1396, acc: 0.7037
# Epoch 24/75
# ----------
# valid loss: 1.2168, acc: 0.6852
# Epoch 25/75
# ----------
# valid loss: 1.1855, acc: 0.6944
# Epoch 26/75
# ----------
# valid loss: 1.2233, acc: 0.6852
# Epoch 27/75
# ----------
# valid loss: 1.1364, acc: 0.7037
# Epoch 28/75
# ----------
# valid loss: 1.1940, acc: 0.7037
# Epoch 29/75
# ----------
# valid loss: 1.2477, acc: 0.6759
# Epoch 30/75
# ----------
# valid loss: 1.2077, acc: 0.6852
# Epoch 31/75
# ----------
# valid loss: 1.2066, acc: 0.6667
# Epoch 32/75
# ----------
# valid loss: 1.1798, acc: 0.6667
# Epoch 33/75
# ----------
# valid loss: 1.1958, acc: 0.7037
# Epoch 34/75
# ----------
# valid loss: 1.2939, acc: 0.7037
# Epoch 35/75
# ----------
# valid loss: 1.2794, acc: 0.6667
# Epoch 36/75
# ----------
# valid loss: 1.2845, acc: 0.6852
# Epoch 37/75
# ----------
# valid loss: 1.3178, acc: 0.6852
# Epoch 38/75
# ----------
# valid loss: 1.2246, acc: 0.6667
# Epoch 39/75
# ----------
# valid loss: 1.2549, acc: 0.7315
# Epoch 40/75
# ----------
# valid loss: 1.2457, acc: 0.6852
# Epoch 41/75
# ----------
# valid loss: 1.3142, acc: 0.6759
# Epoch 42/75
# ----------
# valid loss: 1.2472, acc: 0.7130
# Epoch 43/75
# ----------
# valid loss: 1.2002, acc: 0.7130
# Epoch 44/75
# ----------
# valid loss: 1.2740, acc: 0.6944
# Epoch 45/75
# ----------
# valid loss: 1.2826, acc: 0.6852
# Epoch 46/75
# ----------
# valid loss: 1.2017, acc: 0.7130
# Epoch 47/75
# ----------
# valid loss: 1.2907, acc: 0.7222
# Epoch 48/75
# ----------
# valid loss: 1.2748, acc: 0.7037
# Epoch 49/75
# ----------
# valid loss: 1.3482, acc: 0.6759
# Epoch 50/75
# ----------
# valid loss: 1.3535, acc: 0.6574
# Epoch 51/75
# ----------
# valid loss: 1.3568, acc: 0.6759
# Epoch 52/75
# ----------
# valid loss: 1.3133, acc: 0.7037
# Epoch 53/75
# ----------
# valid loss: 1.3624, acc: 0.7222
# Epoch 54/75
# ----------
# valid loss: 1.3349, acc: 0.6852
# Epoch 55/75
# ----------
# valid loss: 1.3938, acc: 0.7222
# Epoch 56/75
# ----------
# valid loss: 1.3287, acc: 0.7315
# Epoch 57/75
# ----------
# valid loss: 1.4088, acc: 0.6759
# Epoch 58/75
# ----------
# valid loss: 1.4396, acc: 0.6389
# Epoch 59/75
# ----------
# valid loss: 1.3636, acc: 0.6667
# Epoch 60/75
# ----------
# valid loss: 1.3132, acc: 0.6944
# Epoch 61/75
# ----------
# valid loss: 1.4125, acc: 0.6944
# Epoch 62/75
# ----------
# valid loss: 1.4115, acc: 0.6667
# Epoch 63/75
# ----------
# valid loss: 1.2589, acc: 0.7130
# Epoch 64/75
# ----------
# valid loss: 1.1885, acc: 0.7130
# Epoch 65/75
# ----------
# valid loss: 1.3277, acc: 0.7037
# Epoch 66/75
# ----------
# valid loss: 1.3771, acc: 0.6759
# Epoch 67/75
# ----------
# valid loss: 1.3335, acc: 0.6481
# Epoch 68/75
# ----------
# valid loss: 1.2369, acc: 0.7407
# Epoch 69/75
# ----------
# valid loss: 1.2440, acc: 0.7222
# Epoch 70/75
# ----------
# valid loss: 1.2198, acc: 0.7222
# Epoch 71/75
# ----------
# valid loss: 1.2952, acc: 0.7037
# Epoch 72/75
# ----------
# valid loss: 1.4358, acc: 0.6759
# Epoch 73/75
# ----------
# valid loss: 1.2463, acc: 0.6944
# Epoch 74/75
# ----------
# valid loss: 1.3022, acc: 0.7037
# Epoch 75/75
# ----------
# valid loss: 1.2871, acc: 0.7222

# %%
#basecolor
#product
model_trained = train_model(model, criterion, optimizer, dataloaders, scheduler=None, num_epochs=75, cycle_mult=2)
# Out:
# Epoch 1/75
# ----------
# valid loss: 2.3914, acc: 0.2587
# Epoch 2/75
# ----------
# valid loss: 1.9286, acc: 0.3943
# Epoch 3/75
# ----------
# valid loss: 1.7718, acc: 0.4353
# Epoch 4/75
# ----------
# valid loss: 1.5970, acc: 0.4953
# Epoch 5/75
# ----------
# valid loss: 1.5243, acc: 0.5079
# Epoch 6/75
# ----------
# valid loss: 1.5334, acc: 0.5047
# Epoch 7/75
# ----------
# valid loss: 1.4986, acc: 0.5205
# Epoch 8/75
# ----------
# valid loss: 1.4608, acc: 0.5142
# Epoch 9/75
# ----------
# valid loss: 1.5164, acc: 0.5110
# Epoch 10/75
# ----------
# valid loss: 1.4844, acc: 0.5237
# Epoch 11/75
# ----------
# valid loss: 1.4885, acc: 0.5047
# Epoch 12/75
# ----------
# valid loss: 1.5529, acc: 0.5110
# Epoch 13/75
# ----------
# valid loss: 1.5394, acc: 0.5552
# Epoch 14/75
# ----------
# valid loss: 1.6024, acc: 0.5615
# Epoch 15/75
# ----------
# valid loss: 1.6133, acc: 0.5142
# Epoch 16/75
# ----------
# valid loss: 1.6340, acc: 0.5331
# Epoch 17/75
# ----------
# valid loss: 1.7628, acc: 0.4953
# Epoch 18/75
# ----------
# valid loss: 1.6814, acc: 0.5331
# Epoch 19/75
# ----------
# valid loss: 1.6899, acc: 0.5331
# Epoch 20/75
# ----------
# valid loss: 1.6648, acc: 0.5331
# Epoch 21/75
# ----------
# valid loss: 1.7539, acc: 0.5174
# Epoch 22/75
# ----------
# valid loss: 1.8386, acc: 0.5237
# Epoch 23/75
# ----------
# valid loss: 1.7397, acc: 0.5300
# Epoch 24/75
# ----------
# valid loss: 1.8735, acc: 0.5268
# Epoch 25/75
# ----------
# valid loss: 1.7713, acc: 0.5457
# Epoch 26/75
# ----------
# valid loss: 1.7993, acc: 0.5394
# Epoch 27/75
# ----------
# valid loss: 1.7509, acc: 0.5363
# Epoch 28/75
# ----------
# valid loss: 1.7111, acc: 0.5615
# Epoch 29/75
# ----------
# valid loss: 1.8016, acc: 0.5363
# Epoch 30/75
# ----------
# valid loss: 1.8709, acc: 0.5426
# Epoch 31/75
# ----------
# valid loss: 1.8164, acc: 0.5489
# Epoch 32/75
# ----------
# valid loss: 1.9814, acc: 0.5110
# Epoch 33/75
# ----------
# valid loss: 1.8804, acc: 0.5394
# Epoch 34/75
# ----------
# valid loss: 1.9119, acc: 0.5300
# Epoch 35/75
# ----------
# valid loss: 1.9761, acc: 0.5331
# Epoch 36/75
# ----------
# valid loss: 1.8301, acc: 0.5741
# Epoch 37/75
# ----------
# valid loss: 1.8262, acc: 0.5363
# Epoch 38/75
# ----------
# valid loss: 1.8829, acc: 0.5647
# Epoch 39/75
# ----------
# valid loss: 1.9689, acc: 0.5457
# Epoch 40/75
# ----------
# valid loss: 1.8840, acc: 0.5237
# Epoch 41/75
# ----------
# valid loss: 1.8725, acc: 0.5331
# Epoch 42/75
# ----------
# valid loss: 1.9270, acc: 0.5521
# Epoch 43/75
# ----------
# valid loss: 2.0603, acc: 0.5552
# Epoch 44/75
# ----------
# valid loss: 1.9538, acc: 0.5205
# Epoch 45/75
# ----------
# valid loss: 1.9070, acc: 0.5457
# Epoch 46/75
# ----------
# valid loss: 2.0105, acc: 0.5142
# Epoch 47/75
# ----------
# valid loss: 1.9233, acc: 0.5615
# Epoch 48/75
# ----------
# valid loss: 1.9724, acc: 0.5331
# Epoch 49/75
# ----------
# valid loss: 1.9405, acc: 0.5237
# Epoch 50/75
# ----------
# valid loss: 1.9129, acc: 0.5237
# Epoch 51/75
# ----------
# valid loss: 2.0079, acc: 0.5142
# Epoch 52/75
# ----------
# valid loss: 1.9122, acc: 0.5521
# Epoch 53/75
# ----------
# valid loss: 2.0023, acc: 0.5268
# Epoch 54/75
# ----------
# valid loss: 1.9617, acc: 0.5678
# Epoch 55/75
# ----------
# valid loss: 1.9509, acc: 0.5363
# Epoch 56/75
# ----------
# valid loss: 1.9258, acc: 0.5394
# Epoch 57/75
# ----------
# valid loss: 2.0163, acc: 0.5331
# Epoch 58/75
# ----------
# valid loss: 1.8845, acc: 0.5615
# Epoch 59/75
# ----------
# valid loss: 1.8927, acc: 0.5489
# Epoch 60/75
# ----------
# valid loss: 1.8638, acc: 0.5584
# Epoch 61/75
# ----------
# valid loss: 1.8868, acc: 0.5647
# Epoch 62/75
# ----------
# valid loss: 1.9296, acc: 0.5331
# Epoch 63/75
# ----------
# valid loss: 1.9750, acc: 0.5079
# Epoch 64/75
# ----------
# valid loss: 2.0031, acc: 0.5331
# Epoch 65/75
# ----------
# valid loss: 2.0219, acc: 0.5489
# Epoch 66/75
# ----------
# valid loss: 2.0013, acc: 0.5331
# Epoch 67/75
# ----------
# valid loss: 1.9478, acc: 0.5489
# Epoch 68/75
# ----------
# valid loss: 1.8527, acc: 0.5741
# Epoch 69/75
# ----------
# valid loss: 1.8959, acc: 0.5678
# Epoch 70/75
# ----------
# valid loss: 1.8306, acc: 0.5647
# Epoch 71/75
# ----------
# valid loss: 1.8952, acc: 0.5457
# Epoch 72/75
# ----------
# valid loss: 1.8675, acc: 0.5710
# Epoch 73/75
# ----------
# valid loss: 1.8808, acc: 0.5647
# Epoch 74/75
# ----------
# valid loss: 1.9029, acc: 0.5300
# Epoch 75/75
# ----------
# valid loss: 1.8515, acc: 0.5552

# %%
#product + cropped
model_trained = train_model(model, criterion, optimizer, dataloaders, scheduler=None, num_epochs=75, cycle_mult=2)
# Out:
# Epoch 1/75
# ----------
# valid loss: 2.2734, acc: 0.2934
# Epoch 2/75
# ----------
# valid loss: 1.8619, acc: 0.4416
# Epoch 3/75
# ----------
# valid loss: 1.6164, acc: 0.4953
# Epoch 4/75
# ----------
# valid loss: 1.4970, acc: 0.4984
# Epoch 5/75
# ----------
# valid loss: 1.4498, acc: 0.5552
# Epoch 6/75
# ----------
# valid loss: 1.3813, acc: 0.5363
# Epoch 7/75
# ----------
# valid loss: 1.3893, acc: 0.5300
# Epoch 8/75
# ----------
# valid loss: 1.3698, acc: 0.5394
# Epoch 9/75
# ----------
# valid loss: 1.3737, acc: 0.5394
# Epoch 10/75
# ----------
# valid loss: 1.3443, acc: 0.5552
# Epoch 11/75
# ----------
# valid loss: 1.2945, acc: 0.5710
# Epoch 12/75
# ----------
# valid loss: 1.3360, acc: 0.5741
# Epoch 13/75
# ----------
# valid loss: 1.3358, acc: 0.6025
# Epoch 14/75
# ----------
# valid loss: 1.3907, acc: 0.5741
# Epoch 15/75
# ----------
# valid loss: 1.4034, acc: 0.5741
# Epoch 16/75
# ----------
# valid loss: 1.4503, acc: 0.5647
# Epoch 17/75
# ----------
# valid loss: 1.4251, acc: 0.5836
# Epoch 18/75
# ----------
# valid loss: 1.4629, acc: 0.5710
# Epoch 19/75
# ----------
# valid loss: 1.4691, acc: 0.5931
# Epoch 20/75
# ----------
# valid loss: 1.4319, acc: 0.5931
# Epoch 21/75
# ----------
# valid loss: 1.4715, acc: 0.5836
# Epoch 22/75
# ----------
# valid loss: 1.5431, acc: 0.6088
# Epoch 23/75
# ----------
# valid loss: 1.4947, acc: 0.5899
# Epoch 24/75
# ----------
# valid loss: 1.4747, acc: 0.6151
# Epoch 25/75
# ----------
# valid loss: 1.5991, acc: 0.6025
# Epoch 26/75
# ----------
# valid loss: 1.5954, acc: 0.5931
# Epoch 27/75
# ----------
# valid loss: 1.6206, acc: 0.5584
# Epoch 28/75
# ----------
# valid loss: 1.5735, acc: 0.6151
# Epoch 29/75
# ----------
# valid loss: 1.6262, acc: 0.5836
# Epoch 30/75
# ----------
# valid loss: 1.5276, acc: 0.6183
# Epoch 31/75
# ----------
# valid loss: 1.5808, acc: 0.5931
# Epoch 32/75
# ----------
# valid loss: 1.7049, acc: 0.5678
# Epoch 33/75
# ----------
# valid loss: 1.7068, acc: 0.5899
# Epoch 34/75
# ----------
# valid loss: 1.6493, acc: 0.6120
# Epoch 35/75
# ----------
# valid loss: 1.6552, acc: 0.5836
# Epoch 36/75
# ----------
# valid loss: 1.6869, acc: 0.5899
# Epoch 37/75
# ----------
# valid loss: 1.7100, acc: 0.5962
# Epoch 38/75
# ----------
# valid loss: 1.6739, acc: 0.6025
# Epoch 39/75
# ----------
# valid loss: 1.6032, acc: 0.6057
# Epoch 40/75
# ----------
# valid loss: 1.6030, acc: 0.5994
# Epoch 41/75
# ----------
# valid loss: 1.7916, acc: 0.5836
# Epoch 42/75
# ----------
# valid loss: 1.6741, acc: 0.6057
# Epoch 43/75
# ----------
# valid loss: 1.6757, acc: 0.5804
# Epoch 44/75
# ----------
# valid loss: 1.7306, acc: 0.6088
# Epoch 45/75
# ----------
# valid loss: 1.7849, acc: 0.6057
# Epoch 46/75
# ----------
# valid loss: 1.7120, acc: 0.6057
# Epoch 47/75
# ----------
# valid loss: 1.8048, acc: 0.5962
# Epoch 48/75
# ----------
# valid loss: 1.6559, acc: 0.6057
# Epoch 49/75
# ----------
# valid loss: 1.6809, acc: 0.6088
# Epoch 50/75
# ----------
# valid loss: 1.6176, acc: 0.6183
# Epoch 51/75
# ----------
# valid loss: 1.5435, acc: 0.6246
# Epoch 52/75
# ----------
# valid loss: 1.5727, acc: 0.6088
# Epoch 53/75
# ----------
# valid loss: 1.6427, acc: 0.6151
# Epoch 54/75
# ----------
# valid loss: 1.6378, acc: 0.6341
# Epoch 55/75
# ----------
# valid loss: 1.6329, acc: 0.6246
# Epoch 56/75
# ----------
# valid loss: 1.6568, acc: 0.6309
# Epoch 57/75
# ----------
# valid loss: 1.7454, acc: 0.6120
# Epoch 58/75
# ----------
# valid loss: 1.8536, acc: 0.5741
# Epoch 59/75
# ----------
# valid loss: 1.6988, acc: 0.6120
# Epoch 60/75
# ----------
# valid loss: 1.8402, acc: 0.5710
# Epoch 61/75
# ----------
# valid loss: 1.7415, acc: 0.5994
# Epoch 62/75
# ----------
# valid loss: 1.7577, acc: 0.6057
# Epoch 63/75
# ----------
# valid loss: 1.7398, acc: 0.6183
# Epoch 64/75
# ----------
# valid loss: 1.6929, acc: 0.6088
# Epoch 65/75
# ----------
# valid loss: 1.7633, acc: 0.6151
# Epoch 66/75
# ----------
# valid loss: 1.7623, acc: 0.5868
# Epoch 67/75
# ----------
# valid loss: 1.7533, acc: 0.5994
# Epoch 68/75
# ----------
# valid loss: 1.8015, acc: 0.5962
# Epoch 69/75
# ----------
# valid loss: 1.7394, acc: 0.6151
# Epoch 70/75
# ----------
# valid loss: 1.7824, acc: 0.6057
# Epoch 71/75
# ----------
# valid loss: 1.7778, acc: 0.5994
# Epoch 72/75
# ----------
# valid loss: 1.7439, acc: 0.6057
# Epoch 73/75
# ----------
# valid loss: 1.7919, acc: 0.6057
# Epoch 74/75
# ----------
# valid loss: 1.7805, acc: 0.6025
# Epoch 75/75
# ----------
# valid loss: 1.8578, acc: 0.6025
