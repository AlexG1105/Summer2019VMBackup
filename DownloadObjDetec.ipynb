# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/AZG6ELS/Developer/ObjDetec/interior_furniture_images.csv')

# %%
chairDF = df.loc[df['taxonomy'].str.contains('Accent Chairs')]

# %%
df.shape
# Out:
# (120110, 10)

# %%
chairDF.shape
# Out:
# (6732, 10)

# %%
chairDF.to_csv('AccentChairSet.csv')

# %%
import json
from pprint import pprint

with open('/home/azg6els/Downloads/annotations/instances_train2014.json') as f:
    data = json.load(f)

# %%
for i,item in enumerate(data['annotations']):
    if (i == 0):
        print(item)
# Out:
# {'segmentation': [[312.29, 562.89, 402.25, 511.49, 400.96, 425.38, 398.39, 372.69, 388.11, 332.85, 318.71, 325.14, 295.58, 305.86, 269.88, 314.86, 258.31, 337.99, 217.19, 321.29, 182.49, 343.13, 141.37, 348.27, 132.37, 358.55, 159.36, 377.83, 116.95, 421.53, 167.07, 499.92, 232.61, 560.32, 300.72, 571.89]], 'area': 54652.9556, 'iscrowd': 0, 'image_id': 480023, 'bbox': [116.95, 305.86, 285.3, 266.03], 'category_id': 58, 'id': 86}

# %%
for item in data:
    print(item)
# Out:
# info
# images
# licenses
# annotations
# categories

# %%
#modifying some CrowdFlower images
df = pd.read_csv('CrowdFlower/FilteredBedroomRooms.csv')

# %%
df = df.rename({'alt_image_path':'Image_URL'},axis=1)

# %%
df.head(100).to_csv('roomClassification/test_input.csv',index=False)

# %%
df2 = pd.read_csv('roomClassification/test_ouput.csv')

# %%
df2.head(100)
# Out:
#     Unnamed: 0    OMS_SKU                                        description  \
# 0            0  306006166  Vivian Grey Top End Table                     ...
# 1            1  305607241  13 in. 24-Watt Oil Rubbed Bronze Color Changea...
# 2            2  205756036  Matira 3-Light Oil Rubbed Bronze Chandelier   ...
# 3            3  205525449  Cabella Distressed Ash End Table              ...
# 4            4  308608242  Saka Anthracite Modern Side Table             ...
# 5            5  301196573  Bannock 5-Light Heirloom Bronze Chandelier    ...
# 6            6  207155378  Sweet Diamonds Gold/Navy Decorative Pillow    ...
# 7            7  304290779  Estate 9-Light Bronze Chandelier              ...
# 8            8  306191793  Soho Birch Brown and Grey Standard Bookcase   ...
# 9            9  303960812  Newport Antique White Birch Queen Storage Pane...
# 10          10  303824460  White Diamond-Patterned 3-Drawer Chest with Go...
# ...

# %%
df['Image_URL'][85]
# Out:
# 'https://idm.homedepot.com/assets/image/98/98602bb0-5ce4-4482-8450-8de11959cb9a.jpg'

# %%
from PIL import Image
import requests
from io import BytesIO
df = pd.read_csv('roomClassification/PredictRoomInputOutputs/OfficeRooms.csv')

for i,row in enumerate(df.itertuples()):
    if i % 100 == 0:
        print(i)
    try:
        url = row.Image_URL
        response = requests.get(url)
        img = Image.open(BytesIO(response.content))
    except:
        print('gay')
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# gay
# gay

# %%
##Here i want to filter out the rooms that were predicted to not be offices
df = pd.read_csv('roomClassification/PredictRoomInputOutputs/EntrywayRoomsPredictions.csv')
df.head(100)
# Out:
#     Unnamed: 0    OMS_SKU                                        description  \
# 0            0  206766671  Matthias Taupe Accent Ottoman                 ...
# 1            1  304767105  Draper Solid Hardwood 22 in. Wide Mid Century ...
# 2            2  304240559  Natural Wood Distressed Customary Styled Bench...
# 3            3  305664582  Black/Chocolate Microfiber Shoe Rack Organizer...
# 4            4  302252410  Hudson Vintage Industrial Medium Brown Wood Co...
# 5            5  203138756  Black Console Table                           ...
# 6            6  305362535  Artisan Solid Wood 21 in. Wide Square Contempo...
# 7            7  301764091  Flavius Teal Storage Bench                    ...
# 8            8  308262210  Lebrocq Mid-Century Modern Weathered Gray Styl...
# 9            9  307446091  American Heritage Mahogany Baldwin 1-Drawer En...
# 10          10  305703848  Barnett Transitional Square Pouf in Distressed...
# ...

# %%
df = df.loc[df['prediction'] == 'entryway']
df.shape
# Out:
# (823, 13)

# %%
.df.to_csv('roomClassification/PredictRoomInputOutputs/OfficeRoomsFilteredPredictions.csv')
